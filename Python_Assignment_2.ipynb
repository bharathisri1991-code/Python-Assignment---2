# %% [markdown]
# #Python Assignment 2: Data Structures (List, Dictionary, Set) & Conditional Statements

# %% [markdown]
# #List (Creation, Modification and Access):

# %% [markdown]
# #1.List Creation

# %%
age_list = [25,28,27,32,24]

# %%
name_list = ["Arun","Balaji","Kavi","Meena","Diya"]

# %%
print("Age List:",age_list)
print("Name List:",name_list)
# Out:
# Age List: [25, 28, 27, 32, 24]
# Name List: ['Arun', 'Balaji', 'Kavi', 'Meena', 'Diya']

# %% [markdown]
# #2. List Operations / Modifications:

# %% [markdown]
# # a. Append Yazhini

# %%
name_list.append("Yazhini")

# %%
name_list
# Out:
# ['Arun', 'Balaji', 'Kavi', 'Meena', 'Diya', 'Yazhini']

# %% [markdown]
# # b. Insert 30 at index 2

# %%
age_list.insert(2,30)

# %%
age_list
# Out:
# [25, 28, 30, 27, 32, 24]

# %% [markdown]
# # c. Remove Yazhini

# %%
name_list.remove("Yazhini")

# %%
name_list
# Out:
# ['Arun', 'Balaji', 'Kavi', 'Meena', 'Diya']

# %% [markdown]
# # d. Pop last element

# %%
age_list.pop()
# Out:
# 24

# %%
age_list
# Out:
# [25, 28, 30, 27, 32]

# %% [markdown]
# # e. Extend the list

# %%
age_list.extend([29,30,26])

# %%
age_list
# Out:
# [25, 28, 30, 27, 32, 29, 30, 26]

# %% [markdown]
# # f. Sort in descending order

# %%
age_list.sort(reverse=True)

# %%
age_list
# Out:
# [32, 30, 30, 29, 28, 27, 26, 25]

# %% [markdown]
# # g. Max, Min and Sum

# %%
max(age_list)
# Out:
# 32

# %%
min(age_list)
# Out:
# 25

# %%
sum(age_list)
# Out:
# 227

# %% [markdown]
# # 3.Accessing Elements

# %%
name_list[0]
# Out:
# 'Arun'

# %%
name_list[-1]
# Out:
# 'Diya'

# %%
name_list[2:5]
# Out:
# ['Kavi', 'Meena', 'Diya']

# %%
name_list[::-1]
# Out:
# ['Diya', 'Meena', 'Kavi', 'Balaji', 'Arun']

# %% [markdown]
# #Dictionary (Creation, Modification and Access):

# %%
student_mark = {"Arun": 75,"Balaji": 85,"Kavi": 90,"Meena": 78,"Diya": 88}

# %%
student_mark
# Out:
# {'Arun': 75, 'Balaji': 85, 'Kavi': 90, 'Meena': 78, 'Diya': 88}

# %% [markdown]
# # Print one student's mark

# %%
student_mark["Kavi"]
# Out:
# 90

# %% [markdown]
# # Add new student

# %%
student_mark["Janani"] = 80

# %%
student_mark
# Out:
# {'Arun': 75, 'Balaji': 85, 'Kavi': 90, 'Meena': 78, 'Diya': 88, 'Janani': 80}

# %% [markdown]
# # Update mark

# %%
student_mark.update({"Arun": 82})

# %%
student_mark
# Out:
# {'Arun': 82, 'Balaji': 85, 'Kavi': 90, 'Meena': 78, 'Diya': 88, 'Janani': 80}

# %% [markdown]
# # Keys

# %%
print("keys:",student_mark.keys())
# Out:
# keys: dict_keys(['Arun', 'Balaji', 'Kavi', 'Meena', 'Diya', 'Janani'])

# %% [markdown]
# # Values

# %%
print("values:",student_mark.values())
# Out:
# values: dict_values([82, 85, 90, 78, 88, 80])

# %% [markdown]
# # Items

# %%
print("items:",student_mark.items())
# Out:
# items: dict_items([('Arun', 82), ('Balaji', 85), ('Kavi', 90), ('Meena', 78), ('Diya', 88), ('Janani', 80)])

# %% [markdown]
# #Sets (Operations):

# %% [markdown]
# # a. Create Set

# %%
my_set = {'a','e','i','o','u','a','a','i'}

# %%
my_set
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %% [markdown]
# #Explanation:
#           Duplicate values are automatically removed.

# %% [markdown]
# # b. Attempt to change value

# %%
my_set[4] = 's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3852/726852993.py in <cell line: 0>()
# ----> 1 my_set[4] = 's'
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# #Explanation:
# The code throws a TypeError because a set is an unordered collection and does not support indexing or item assignment. Therefore, elements in a set cannot be modified using an index like my_set[4] = 's'.

# %% [markdown]
# # c. Create two sets

# %%
set1 = {1,3,5,7,9}
set2 = {2,3,5,8,10}

# %% [markdown]
# # d. Union

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %% [markdown]
# # Intersection

# %%
set1.intersection(set2)
# Out:
# {3, 5}

# %% [markdown]
# #Operators & Conditional Statements :
# (IF, ELIF, ELSE)

# %% [markdown]
# #Performance Category Program:

# %%
score = int(input("Enter Your Score (0 to 10): "))
if score <0 or score >10:
  print("Invalid Score")
elif score >7:
  print("Above Average")
  print("Excellent! Keep up the great work.")
elif score >=4:
  print("Average")
  print("Good effort! Keep practicing, there's room for improvement.")
else:
  print("Below Average")
  print("Need to improve your performance. Consistent practice will lead to better results.")
# Out:
# Enter Your Score (0 to 10): 8
# Above Average
# Excellent! Keep up the great work.
